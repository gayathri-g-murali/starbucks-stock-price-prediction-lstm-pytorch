# %% [markdown]
# # STARBUCKS STOCK PRICE PREDICTION - LSTM - IMPLEMENTATION

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![Starbucks-New-Cortado-Pistachio-Latte-and-Reformulated-Matcha-FT-BLOG1224-b28767a4d8bf4dcab87fc5f8321fff47.jpg](attachment:088ec7da-dcf8-47af-aa82-a9593a1dea92.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import root_mean_squared_error

# %%
df = pd.read_csv('Starbucks_Stock_Data.csv')
df.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1992-06-26 00:00:00-04:00  0.246819  0.261510  0.240942  0.252696
# 1  1992-06-29 00:00:00-04:00  0.255634  0.276202  0.249757  0.270325
# 2  1992-06-30 00:00:00-04:00  0.276202  0.279141  0.258572  0.261510
# 3  1992-07-01 00:00:00-04:00  0.264449  0.270325  0.255634  0.267387
# 4  1992-07-02 00:00:00-04:00  0.270325  0.270325  0.261510  0.267387
#
#       Volume ticker                                          name
# 0  224358400   SBUX  Starbucks Corporation (SBUX) Historical Data
# 1   58732800   SBUX  Starbucks Corporation (SBUX) Historical Data
# 2   34777600   SBUX  Starbucks Corporation (SBUX) Historical Data
# 3   18316800   SBUX  Starbucks Corporation (SBUX) Historical Data
# 4   13996800   SBUX  Starbucks Corporation (SBUX) Historical Data

# %%
df.tail()
# Out:
#                            Date       Open       High        Low      Close  \
# 8371  2025-09-26 00:00:00-04:00  83.849998  84.620003  82.900002  83.389999
# 8372  2025-09-29 00:00:00-04:00  83.650002  85.839996  83.550003  85.639999
# 8373  2025-09-30 00:00:00-04:00  85.230003  85.250000  84.180000  84.599998
# 8374  2025-10-01 00:00:00-04:00  84.459999  85.139999  83.959999  84.400002
# 8375  2025-10-02 00:00:00-04:00  84.250000  87.059998  84.029999  86.785004
#
#         Volume ticker                                          name
# 8371   6955500   SBUX  Starbucks Corporation (SBUX) Historical Data
# 8372  11222800   SBUX  Starbucks Corporation (SBUX) Historical Data
# 8373   7570300   SBUX  Starbucks Corporation (SBUX) Historical Data
# 8374   8153300   SBUX  Starbucks Corporation (SBUX) Historical Data
# 8375   5682922   SBUX  Starbucks Corporation (SBUX) Historical Data

# %%
# Shape
df.shape
# Out:
# (8376, 8)

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8376 entries, 0 to 8375
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8376 non-null   object
#  1   Open    8376 non-null   float64
#  2   High    8376 non-null   float64
#  3   Low     8376 non-null   float64
#  4   Close   8376 non-null   float64
#  5   Volume  8376 non-null   int64
#  6   ticker  8376 non-null   object
#  7   name    8376 non-null   object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 523.6+ KB

# %%
# Summary
df.describe()
# Out:
#               Open         High          Low         Close        Volume
# count  8376.000000  8376.000000  8376.000000  8.376000e+03  8.376000e+03
# mean     28.447721    28.735025    28.155943  6.107817e-17  1.454072e+07
# std      32.716945    33.023940    32.403189  1.000060e+00  1.329226e+07
# min       0.246819     0.261510     0.240942 -8.618998e-01  1.504000e+06
# 25%       3.467216     3.555073     3.384943 -7.634743e-01  7.789375e+06
# 50%      10.675733    10.778799    10.559142 -5.437697e-01  1.148610e+07
# 75%      48.060541    48.382775    47.664283  5.985825e-01  1.755560e+07
# max     114.473497   115.874326   113.251502  2.626368e+00  5.855088e+08

# %%
# Null Values
df.isna().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# ticker    0
# name      0
# dtype: int64

# %%
# Duplicated Values
df.duplicated().sum().sum()
# Out:
# 0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date', inplace = True)
df.sort_index()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 1992-06-26 00:00:00-04:00   0.246819   0.261510   0.240942   0.252696
# 1992-06-29 00:00:00-04:00   0.255634   0.276202   0.249757   0.270325
# 1992-06-30 00:00:00-04:00   0.276202   0.279141   0.258572   0.261510
# 1992-07-01 00:00:00-04:00   0.264449   0.270325   0.255634   0.267387
# 1992-07-02 00:00:00-04:00   0.270325   0.270325   0.261510   0.267387
# ...                              ...        ...        ...        ...
# 2025-09-26 00:00:00-04:00  83.849998  84.620003  82.900002  83.389999
# 2025-09-29 00:00:00-04:00  83.650002  85.839996  83.550003  85.639999
# 2025-09-30 00:00:00-04:00  85.230003  85.250000  84.180000  84.599998
# 2025-10-01 00:00:00-04:00  84.459999  85.139999  83.959999  84.400002
# 2025-10-02 00:00:00-04:00  84.250000  87.059998  84.029999  86.785004
#
#                               Volume ticker  \
# Date
# 1992-06-26 00:00:00-04:00  224358400   SBUX
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label = 'Close Price', color = 'darkgreen')
plt.title('Starbucks Stock Close Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Standard Scaler
scaler = StandardScaler()
df['Close'] = scaler.fit_transform(df[['Close']])
df.Close
# Out:
# Date
# 1992-06-26 00:00:00-04:00   -0.861900
# 1992-06-29 00:00:00-04:00   -0.861361
# 1992-06-30 00:00:00-04:00   -0.861630
# 1992-07-01 00:00:00-04:00   -0.861451
# 1992-07-02 00:00:00-04:00   -0.861451
#                                ...
# 2025-09-26 00:00:00-04:00    1.679040
# 2025-09-29 00:00:00-04:00    1.747807
# 2025-09-30 00:00:00-04:00    1.716021
# 2025-10-01 00:00:00-04:00    1.709909
# 2025-10-02 00:00:00-04:00    1.782802
# Name: Close, Length: 8376, dtype: float64

# %%
seq_length = 30
data = []

for i in range(len(df) - seq_length):
    data.append(df.Close[i:i+seq_length])
data = np.array(data)
